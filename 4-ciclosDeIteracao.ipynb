# %%
# %pip install iplantuml
import iplantuml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %%plantuml
#
# @startgantt
# printscale daily zoom 2
# saturday are closed
# sunday are closed
#
# Project starts the 1st of january 2024
# [Elemento de iteracao] as [CADASTRAR] lasts 5 weeks
# [CADASTRAR] is colored in Lavender/DarkBlue
#
# [Requisitos] as [REQUERIMENTOS_FULL] lasts 1 week
# [REQUERIMENTOS_FULL] is colored in Lavender/LightBlue
# [Desenvolvimento] as [DEV_FULL] lasts 4 week
# [DEV_FULL] starts 8th of january 2024
# [DEV_FULL] is colored in Lavender/LightBlue
#
# [DEV_FULL] displays on same row as [REQUERIMENTOS_FULL]
#
# -- front-end --
# [Requerimentos front] as [REQUERIMENTOS_FRONT] lasts 1 week
# [REQUERIMENTOS_FRONT] is colored in Lavender/LightBlue
#
# [fluxo de tela] as [FLUXO_TELA1] lasts 2 days
# [design de tela] as [DESIGN_TELA1] lasts 2 days
# [apresentar tela] as [ENTREGA_TELA1] lasts 1 day
#
# [ENTREGA_TELA1] is colored in salmon/Lavender
# [FLUXO_TELA1] lasts 2 days
# [FLUXO_TELA1]->[DESIGN_TELA1]
# [DESIGN_TELA1] lasts 2 days
# [DESIGN_TELA1]->[ENTREGA_TELA1]
# [ENTREGA_TELA1] lasts 1 days
#
# [ajustes front-end 1] as [REFAC_FRONT1] lasts 4 days
# [codigo front-end 1] as [DEV_FRONT1] lasts 4 days
#
# [apresentar codigo front-end] as [ENTREGA_TELA2] lasts 1 day
# [ENTREGA_TELA2] is colored in salmon/Lavender
#
# [ENTREGA_TELA1]->[REFAC_FRONT1]
# [ENTREGA_TELA1]->[DEV_FRONT1]
# [REFAC_FRONT1]->[ENTREGA_TELA2]
# [DEV_FRONT1]->[ENTREGA_TELA2]
#
# [ajustes front-end 2] as [REFAC_FRONT2] lasts 4 days
# [testes unitarios front-end] as [TEST_UNIT_FRONT] lasts 2 weeks
# [ENTREGA_TELA1]->[TEST_UNIT_FRONT]
#
# [ENTREGA_TELA2]->[REFAC_FRONT2]
#
#
# -- back-end --
#
# [Requerimentos back-end] as [REQUERIMENTOS_BACK] lasts 1 week
# [REQUERIMENTOS_BACK] is colored in Lavender/LightBlue
# [criar BD] as [BD_CADASTRO] lasts 2 days
# [conectar BD: CRUD] as [CRUD_CADASTRO] lasts 2 days
# [apresentar CRUD] as [ENTREGA_CRUD] lasts 1 day
# [ENTREGA_CRUD] is colored in salmon/Lavender
#
# [BD_CADASTRO]->[CRUD_CADASTRO]
# [CRUD_CADASTRO]->[ENTREGA_CRUD]
#
# [ajustes back-end 1] as [REFAC_BACK1] lasts 4 days
# [codigo back-end 1] as [DEV_BACK1] lasts 4 days
#
# [apresentar codigo back-end] as [ENTREGA_FUNC1] lasts 1 day
# [ENTREGA_FUNC1] is colored in salmon/Lavender
#
# [ENTREGA_CRUD]->[REFAC_BACK1]
# [ENTREGA_CRUD]->[DEV_BACK1]
# [REFAC_BACK1]->[ENTREGA_FUNC1]
# [DEV_BACK1]->[ENTREGA_FUNC1]
#
# [ajustes back-end 2] as [REFAC_BACK2] lasts 4 days
# [testes unitarios back-end] as [TEST_UNIT_BACK] lasts 2 weeks
# [ENTREGA_CRUD]->[TEST_UNIT_BACK]
#
# [ENTREGA_FUNC1]->[REFAC_BACK2]
#
# -- integracao --
#
# [Planejamento de integracao] as [PLAN_INTEG1] lasts 3 days
# [PLAN_INTEG1] is colored in salmon/Lavender
#
# [codigo de integracao] as [DEV_INTEG1] lasts 2 weeks
#
# [ENTREGA_FUNC1]->[PLAN_INTEG1]
# [ENTREGA_TELA2]->[PLAN_INTEG1]
#
# [PLAN_INTEG1]->[DEV_INTEG1]
#
# [testes de integracao] as [TEST_INTEG] lasts 4 days
# [PLAN_INTEG1]->[TEST_INTEG]
#
# [apresentacao parcial] as [PART_CADASTRO] lasts 3 days
# [PART_CADASTRO] is colored in salmon/Lavender
# [PART_CADASTRO] starts 24th of january 2024
#
# [TEST_INTEG]->[PART_CADASTRO]
#
# [ajustes integracao 1] as [REFAC_INTEG1] lasts 3 days
# [PART_CADASTRO]->[REFAC_INTEG1]
#
# [versao finalizada] as [FIM_CADASTRO] lasts 1 day
# [FIM_CADASTRO] is colored in salmon/Lavender
# [REFAC_INTEG1]->[FIM_CADASTRO]
# [DEV_INTEG1]->[FIM_CADASTRO]
#
# [analise de requisitos] as [ANAL_REQ] lasts 2 days
# [ANAL_REQ] is colored in salmon/Lavender
# [DEV_INTEG1]->[ANAL_REQ]
#
# @endgantt

# %%
# %%plantuml
#
# @startgantt
# printscale weekly
#
# Project starts the 1st of january 2024
# [Desenvolvimento por casos de uso] as [PROJ] lasts 50 weeks
# [PROJ] is colored in Lavender/DarkBlue
#
# [Cadastrar] as [CADASTRAR] lasts 5 weeks and starts 1st of january 2024
# [Assinar premium] as [PREMIUM] lasts 5 weeks and starts 1st of january 2024
#
# [Conectar redes sociais] as [CONEC_REDES] lasts 5 weeks
# [Login] as [LOGIN] lasts 5 weeks
# [CRUD usuarios] as [CRUD_USR] lasts 5 weeks
# [CADASTRAR]->[CONEC_REDES]
# [PREMIUM]->[CONEC_REDES]
# [PREMIUM]->[LOGIN]
# [PREMIUM]->[CRUD_USR]
#
# [Curtir] as [CURTIR] lasts 5 weeks
# [Editar perfil] as [EDITAR] lasts 5 weeks
# [CONEC_REDES]->[CURTIR]
# [LOGIN]->[EDITAR]
# [CRUD_USR]->[EDITAR]
#
# [Gerenciar hist. de chat] as [GER_HIST_CHAT] lasts 5 weeks
# [Usar chat] as [CHAT] lasts 5 weeks
# [CURTIR]->[GER_HIST_CHAT]
# [EDITAR]->[CHAT]
#
# [Fazer match] as [MATCH] lasts 5 weeks
# [Notificar usuario] as [NOTIF] lasts 5 weeks
# [Classificar match] as [CLASS_MATCH] lasts 5 weeks
# [GER_HIST_CHAT]->[MATCH]
# [GER_HIST_CHAT]->[NOTIF]
# [GER_HIST_CHAT]->[CLASS_MATCH]
# [CHAT]->[MATCH]
# [CHAT]->[NOTIF]
# [CHAT]->[CLASS_MATCH]
#
# [Entrar anonimo] as [ANONIMO] lasts 5 weeks
# [Remover perfil] as [REMOVER] lasts 5 weeks
# [Enviar feedback] as [FEEDBACK] lasts 5 weeks
# [MATCH]->[ANONIMO]
# [NOTIF]->[REMOVER]
# [CLASS_MATCH]->[FEEDBACK]
# [CLASS_MATCH]->[ANONIMO]
# [CLASS_MATCH]->[REMOVER]
# [CLASS_MATCH]->[FEEDBACK]
#
# [Buscar] as [BUSCAR] lasts 5 weeks
# [Bloquear] as [BLOQUEAR] lasts 5 weeks
# [Listar matches] as [LISTAR_MATCH] lasts 5 weeks
# [ANONIMO]->[BUSCAR]
# [REMOVER]->[BLOQUEAR]
# [FEEDBACK]->[LISTAR_MATCH]
# [FEEDBACK]->[BUSCAR]
# [FEEDBACK]->[BLOQUEAR]
# [FEEDBACK]->[LISTAR_MATCH]
#
# [Destacar perfil] as [DESTACAR] lasts 5 weeks
# [Denunciar usuario] as [DENUNCIAR] lasts 5 weeks
#
# [BUSCAR]->[DESTACAR]
# [BLOQUEAR]->[DESTACAR]
# [LISTAR_MATCH]->[DESTACAR]
# [BUSCAR]->[DENUNCIAR]
# [BLOQUEAR]->[DENUNCIAR]
# [LISTAR_MATCH]->[DENUNCIAR]
#
# [Criar categ. interesse] as [CATEG_INTER] lasts 5 weeks
# [Banir usuario] as [BANIR] lasts 5 weeks
# [Congelar usuario] as [CONGELAR] lasts 5 weeks
# [DESTACAR]->[CATEG_INTER]
# [DESTACAR]->[BANIR]
# [DESTACAR]->[CONGELAR]
# [DENUNCIAR]->[CATEG_INTER]
# [DENUNCIAR]->[BANIR]
# [DENUNCIAR]->[CONGELAR]
#
# [Desconto encontros] as [DESCONTO] lasts 5 weeks
# [Acessar info. adic.] as [INFO_ADD] lasts 5 weeks
# [CATEG_INTER]->[DESCONTO]
# [BANIR]->[DESCONTO]
# [CONGELAR]->[DESCONTO]
# [CONGELAR]->[INFO_ADD]
# [CONGELAR]->[INFO_ADD]
# [CONGELAR]->[INFO_ADD]
#
# @endgantt
